# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Set Seaborn style
sns.set(style="whitegrid")

# %%
# Load the dataset
data = pd.read_csv("sales_data.csv")

# Inspect the first few rows
data.head()
# Out:
#        Date Region    Product    Sales  Quantity  Discount   Category
# 0  1/2/2023  South  Product C  1613.42         7      0.01   Clothing
# 1  1/3/2023   East  Product B  1014.89         5      0.22    Grocery
# 2  1/3/2023  North  Product B   322.89         1      0.03  Furniture
# 3  1/4/2023  North  Product C   337.85        13      0.09    Grocery
# 4  1/4/2023  North  Product C  1402.57        18      0.00    Grocery

# %%
# Checking for missing values
print(data.isnull().sum())
# Out:
# Date        0
# Region      0
# Product     0
# Sales       0
# Quantity    0
# Discount    0
# Category    0
# dtype: int64

# %%
# Convert 'Date' to datetime format
data['Date'] = pd.to_datetime(data['Date'])

# Check data types
print(data.dtypes)
# Out:
# Date        datetime64[ns]
# Region              object
# Product             object
# Sales              float64
# Quantity             int64
# Discount           float64
# Category            object
# dtype: object

# %%
print(data.describe())
# Out:
#                              Date        Sales    Quantity    Discount
# count                         500   500.000000  500.000000  500.000000
# mean   2023-06-30 23:19:40.800000  1036.191020   10.656000    0.149500
# min           2023-01-02 00:00:00   109.390000    1.000000    0.000000
# 25%           2023-03-29 18:00:00   545.377500    5.000000    0.070000
# 50%           2023-07-06 12:00:00  1044.430000   11.000000    0.150000
# 75%           2023-10-03 00:00:00  1476.677500   16.000000    0.230000
# max           2023-12-28 00:00:00  1998.890000   20.000000    0.300000
# std                           NaN   549.707559    5.798699    0.088313

# %%
# Aggregate sales by date
daily_sales = data.groupby('Date')['Sales'].sum().reset_index()

# Plot sales over time
plt.figure(figsize=(12, 6))
sns.lineplot(data=daily_sales, x='Date', y='Sales')
plt.title("Daily Sales Over Time")
plt.show()

# %%
# Aggregate sales by region
region_sales = data.groupby('Region')['Sales'].sum().reset_index()

# Plot sales by region
plt.figure(figsize=(10, 6))
sns.barplot(data=region_sales, x='Region', y='Sales', palette="viridis")
plt.title("Sales by Region")
plt.show()
# Out:
# C:\Users\mk\AppData\Local\Temp\ipykernel_6896\2392283420.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=region_sales, x='Region', y='Sales', palette="viridis")
